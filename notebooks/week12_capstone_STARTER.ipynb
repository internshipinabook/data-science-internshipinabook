# %% [markdown]
# <a href="https://colab.research.google.com/github/internshipinabook/data-science-internshipinabook/blob/main/notebooks/week12_capstone_STARTER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > ⏸️ **Pause and Predict**
# > Before writing a single line of code: write a one-paragraph description of what your capstone will demonstrate. What problem? What data? What model? What did you learn that Week 0 you did not know?

# %%
# ── Colab setup (skip if running locally) ────────────────────────────────────
import os
if not os.path.exists('requirements.txt'):
    # !git clone https://github.com/internshipinabook/data-science-internshipinabook.git book
    # %cd book
    # !pip install -r requirements.txt -q
    print('Colab setup complete ✅')
else:
    print('Running locally ✅')

# %% [markdown]
# # Week 12 — Capstone
# ### Week 12 — The Data Science Internship | Kova Analytics
#
# > **STARTER notebook.**
#
#
# ### The Data Science Internship | Kova Analytics📘 Companion notebook for:
#
#
# **The Data Science Internship**
# Book 0 of 9 in the InternshipInABook™ Series
#
# This repository contains the practical exercises from the book.
#
#
# 📖 Complete internship experience:
#
#
# 1. Workplace scenarios
# 2. Mentor guidance
# 3. Reflection exercises
# 4. Portfolio
# 5. checkpoints
# 6. Capstone projects
#
#
# 👉 Get the complete book:
# https://selar.com/al990ay7ux
#
#
#
# # 🚀 Start Here
#
# Welcome to The Data Science Internship.
#
# If you are new to the InternshipInABook™ Series:
#
# 1. Run this setup notebook.
# 2. Complete Week 1.
# 3. Follow the weekly internship schedule.
# 4. Build your portfolio.
# 5. Complete the capstone project.
#
# 🔗 Repository:
# https://github.com/internshipinabook/data-science-internshipinabook
#
# Run every cell top to bottom. Each cell prints ✅ if everything is working or ❌ with a fix instruction.
# Complete every fix before moving to Week 1.
#
# ---
#
# ---

# %% [markdown]
# ## 📂 Dataset
#
# The dataset is included in the course repository. No Kaggle account required.
#
# **File:** `customer_churn.csv`
# **Source:** `https://raw.githubusercontent.com/internshipinabook/data-science-internshipinabook/main/data/customer_churn.csv`
#
# Run the cell below to load it directly.

# %% [markdown]
# ## ⚠️ Common Mistakes
#
# | Mistake | What goes wrong | Fix |
# |---------|-----------------|-----|
# | Submitting a notebook full of dead-end cells | Your portfolio is a professional document. Dead ends, commented-out experiments, and debugging cells belong in a scratch notebook, not your final submission. | Final submission: only the cells that tell the story from data to decision |
# | Skipping the retrospective | The retrospective is how interviewers know you can reflect and grow. 'I built X' is not as impressive as 'I built X, it failed because Y, and I learned Z'. | Write the retrospective even if you think everything went perfectly — especially then |

# %% [markdown]
# ## 🏆 Challenge Task
#
# > 🎯 **Core Path**
# > Assemble your complete portfolio: clean notebooks, model card v2, fairness audit, dashboard, and a polished README. Push everything to GitHub with a v1.0 release tag.
#
# > 🔬 **Advanced Path**
# > Write a one-page retrospective. What would you do differently in Weeks 1, 4, and 7? What is the single most important thing you learned that surprised you?

# %% [markdown]
# ## ✅ What You Can Do After This Week
#
# - Apply the full twelve-week pipeline independently on a new combined dataset
# - Identify column duplication across merged data sources and resolve it
# - Handle MNAR missing values correctly — `avg_resolution_days` for customers with no tickets
# - Extend a fairness audit to include a new demographic variable — region
# - Write a four-question reflection with a concrete forward-looking action
#
# *Add `capstone.ipynb` to your internship portfolio. You have completed Book 1.*

# %% [markdown]
# <a href="https://colab.research.google.com/github/internshipinabook/data-science-internshipinabook/blob/main/notebooks/week12_capstone_STARTER.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>&nbsp;&nbsp;
# <a href="https://github.com/internshipinabook/data-science-internshipinabook/blob/main/notebooks/week12/week12_capstone_STARTER.ipynb">
#   <img src="https://img.shields.io/badge/View%20on-GitHub-181717?logo=github" alt="View on GitHub"/>
# </a>
#
# ---
#
# ## 🖥️ How to Run This Notebook
#
# | Platform | Instructions |
# |----------|-------------|
# | **Google Colab** | Click the badge above — free, no setup needed |
# | **Local Jupyter** | `pip install -r requirements.txt` then `jupyter lab` |
# | **VS Code** | Open `.ipynb` with the Jupyter extension installed |
# | **GitHub** | Click "View on GitHub" above for a read-only preview |
#
# > **STARTER notebook** — Complete the `# YOUR CODE HERE` cells. Check the SOLUTION notebook if stuck.

# %%
# ── PLATFORM SETUP ───────────────────────────────────────────────────────────
# Run this cell first. It installs missing libraries in Google Colab.
# In a local environment, skip it if requirements.txt is already installed.

import sys, subprocess

IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    print("📦 Google Colab detected — installing libraries...")
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q',
                    'pandas>=1.5', 'numpy>=1.23', 'matplotlib>=3.6',
                    'seaborn>=0.12', 'scikit-learn>=1.2'], check=True)
    print("✅ Libraries installed.")
else:
    print("💻 Running locally.")
    print("   If you see ImportError below, run: pip install -r requirements.txt")

# %% [markdown]
# ## 📂 Dataset
#
# The dataset is included in the course repository. No Kaggle account required.
#
# **File:** `customer_churn.csv`
# **Source:** `https://raw.githubusercontent.com/internshipinabook/data-science-internshipinabook/main/data/customer_churn.csv`
#
# Run the cell below to load it directly.

# %% [markdown]
# ## 🔄 Adaptability — Use Your Own Dataset
#
# This notebook is written for the Telco Churn dataset but the **entire ML pipeline works on any binary classification problem**.
#
# **To swap in your own data, change only these lines at the top of the notebook:**
# ```python
# DATA_FILE      = 'customer_churn.csv'  # ← your CSV filename
# TARGET_COL     = 'Churn'              # ← the binary column you want to predict (Yes/No or 1/0)
# POSITIVE_LABEL = 'Yes'                # ← which value means "positive" (the event you care about)
# ID_COL         = 'customerID'         # ← identifier column to drop before modelling (or None)
# NUMERIC_FIX    = 'TotalCharges'       # ← any numeric column stored as text (or None)
# ```
#
# **Works with any binary classification dataset:**
# - 🏦 Loan default prediction
# - 🏥 Patient readmission risk
# - 📧 Email spam detection
# - 💳 Credit card fraud
# - 🛒 Customer conversion
# - 🎓 Student dropout prediction
#
# > ⚠️ **Class imbalance warning:** If your dataset has <20% positive class, use `class_weight='balanced'` — already done in this notebook. Check your class distribution in Step 4 before proceeding.
#
# ---

# %% [markdown]
# ## 🔄 Using a Different Dataset?
#
# This notebook is written for `customer_churn.csv` but the ML pipeline applies to any binary classification problem.
#
# **To adapt:**
# 1. Change `DATA_FILE` to your filename
# 2. Set `TARGET_COL` to your binary target column (the thing you want to predict)
# 3. Update `POSITIVE_LABEL` to the positive class name (e.g. `'Yes'`, `'1'`, `'Fraud'`)
# 4. The `prepare_dataset()` function encodes features — update the column references to match yours
#
# ```python
# # ── Adapt these for your dataset ─────────────────────────────────────────────
# DATA_FILE      = 'customer_churn.csv'   # ← change to your file
# TARGET_COL     = 'Churn'               # ← your binary target column
# POSITIVE_LABEL = 'Yes'                 # ← the positive class value
# ID_COL         = 'customerID'          # ← identifier column to drop (or None)
# ```
#
# **Works with any binary classification dataset** — fraud detection, disease prediction,
# loan default, email spam, customer conversion — as long as your target has two classes.
#
# ---

# %% [markdown]
# ## The Brief (Dana, Monday 8:38am)
#
# > *"This week you work alone. No brief for each task. No standup check-ins.
# > Take everything you have built in the last eleven weeks and do it again —
# > end to end — on the new dataset. It has problems. Some you have seen before.
# > Some you have not.*
# >
# > *This is not a test. There are no right answers. There is only the quality
# > of your reasoning and the honesty of your documentation.*
# >
# > *Trust what you know."*
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.dummy import DummyClassifier
from sklearn.metrics import (recall_score, precision_score, f1_score,
                              classification_report, confusion_matrix, roc_curve, auc)

# %matplotlib inline
sns.set_theme(style='whitegrid')
print('✅ Libraries loaded — Capstone ready')

# %% [markdown]
# ## Step 0 — Build the Capstone Dataset
# Run this cell once. Then load the saved CSV fresh — do not read this code to find the issues.

# %%
import pandas as pd, os

# Smart loader — tries local package first, then GitHub, then generates sample data
LOCAL_PATH = '../data/customer_churn.csv'
REMOTE_URL = 'https://raw.githubusercontent.com/internshipinabook/data-science-internshipinabook/main/data/customer_churn.csv'

df = None
if os.path.exists(LOCAL_PATH):
    df = pd.read_csv(LOCAL_PATH)
    print(f'Loaded from local package ✅')
else:
    try:
        df = pd.read_csv(REMOTE_URL)
        print(f'Loaded from GitHub repository ✅')
    except Exception as e:
        print(f'⚠️  Dataset not yet available online ({e})')
        print('Generating sample data for now — upload customer_churn.csv to the data/ folder')
        import numpy as np; np.random.seed(42)
        n = 200
        df = pd.DataFrame({
            'customerID': [f'CUST-{i:04d}' for i in range(n)],
            'gender': np.random.choice(['Male','Female'], n),
            'SeniorCitizen': np.random.choice([0,1], n),
            'tenure': np.random.randint(0, 72, n),
            'MonthlyCharges': np.round(np.random.uniform(20,120,n),2),
            'TotalCharges': np.round(np.random.uniform(100,8000,n),2),
            'Contract': np.random.choice(['Month-to-month','One year','Two year'], n),
            'Churn': np.random.choice(['Yes','No'], n, p=[0.27,0.73]),
        })
        print('Sample dataset ready (200 rows) ✅')

print(f'Shape: {df.shape[0]:,} rows × {df.shape[1]} columns')
df.head()

# %% [markdown]
# ## 1. Problem Statement
# Load the dataset fresh. Write a complete five-question problem statement before any analysis.

# %%
import pandas as pd, os

# Smart loader — tries local package first, then GitHub, then generates sample data
LOCAL_PATH = '../data/customer_churn.csv'
REMOTE_URL = 'https://raw.githubusercontent.com/internshipinabook/data-science-internshipinabook/main/data/customer_churn.csv'

df = None
if os.path.exists(LOCAL_PATH):
    df = pd.read_csv(LOCAL_PATH)
    print(f'Loaded from local package ✅')
else:
    try:
        df = pd.read_csv(REMOTE_URL)
        print(f'Loaded from GitHub repository ✅')
    except Exception as e:
        print(f'⚠️  Dataset not yet available online ({e})')
        print('Generating sample data for now — upload customer_churn.csv to the data/ folder')
        import numpy as np; np.random.seed(42)
        n = 200
        df = pd.DataFrame({
            'customerID': [f'CUST-{i:04d}' for i in range(n)],
            'gender': np.random.choice(['Male','Female'], n),
            'SeniorCitizen': np.random.choice([0,1], n),
            'tenure': np.random.randint(0, 72, n),
            'MonthlyCharges': np.round(np.random.uniform(20,120,n),2),
            'TotalCharges': np.round(np.random.uniform(100,8000,n),2),
            'Contract': np.random.choice(['Month-to-month','One year','Two year'], n),
            'Churn': np.random.choice(['Yes','No'], n, p=[0.27,0.73]),
        })
        print('Sample dataset ready (200 rows) ✅')

print(f'Shape: {df.shape[0]:,} rows × {df.shape[1]} columns')
df.head()

# %% [markdown]
# ### Problem Statement
# **What are we predicting?**
#
# **Why does it matter — and what are the costs of each error type?**
#
# **What type of problem is this?**
#
# **What does success look like in concrete, measurable terms?**
#
# **What could go wrong?**

# %% [markdown]
# ## 2. The Twelve-Week Map
# Write the six-step workflow from memory. Apply it to this project.

# %% [markdown]
# ### My Six-Step Map Applied to the Capstone
#
# **Step 1 — Understand the problem:**
#
# **Step 2 — Get and explore the data:**
#
# **Step 3 — Clean the data:**
#
# **Step 4 — Analyse and model:**
#
# **Step 5 — Evaluate:**
#
# **Step 6 — Communicate:**

# %% [markdown]
# ## 3. First Look
# Shape, dtypes, missing values, class distribution, unique values. Find at least three suspicious things.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Suspicious Findings
# 1.
# 2.
# 3.

# %% [markdown]
# ## 4. Data Quality Issues
# Identify and document BOTH introduced issues before cleaning.
#
# > 💡 Hint: Check whether any two columns appear to measure the same underlying variable.
# > Also check your identifier column for anomalies.

# %% [markdown]
# ### Issues Found
#
# **Issue 1 (describe it here before fixing it):**
#
# **Issue 2 (describe it here before fixing it):**

# %% [markdown]
# ## 5. Cleaning Pipeline
# Apply the Week 3 discipline:
# - Resolve near-duplicate columns
# - Handle corrupted identifiers
# - Classify `avg_resolution_days` as MCAR, MAR, or MNAR — then impute correctly
# - Fix data types, check duplicates, investigate outliers
# - Standardise column names
# - Document every decision in the cleaning log
#
# > 💡 **`avg_resolution_days`:** Customers with no support tickets have NaN here.
# > This is Missing Not at Random — the value is absent for a specific, known reason.
# > Impute with 0, not the column median.

# %%
# YOUR CODE HERE — full cleaning pipeline
# Work on df_clean = df.copy()

# %%
cleaning_log = []
# cleaning_log.append({
#     'column': '...',
#     'issue': '...',
#     'action': '...',
#     'rows_affected': 0,
#     'risk': 'Low / Medium / High'
# })
print(pd.DataFrame(cleaning_log).to_string(index=False))

# %%
# Save the cleaned dataset
# df_clean.to_csv('capstone_clean.csv', index=False)
# print(f'✅ Saved: {df_clean.shape}')

# %% [markdown]
# ## 6. EDA and Feature Engineering
# - Histograms for all numerical columns — name the distribution shapes
# - Correlation heatmap with written interpretation
# - Grouped analysis: churn rate by contract type, region, tenure segment, support ticket count
# - At least three engineered features with hypothesis assessments
#
# > 💡 **Feature worth engineering:** The ratio of `support_tickets` to `tenure` captures
# > something neither raw column does alone — how frequently a customer contacts support
# > per month of service. A customer who raised 5 tickets in 6 months is very different
# > from one who raised 5 tickets over 5 years. Consider whether this distinction matters
# > for predicting disengagement, and build a feature that tests the hypothesis.

# %%
# YOUR CODE HERE — EDA

# %%
# YOUR CODE HERE — feature engineering (at least 3 features with hypotheses)

# %% [markdown]
# ## 7. Modelling
# Apply the full Week 5–8 pipeline. **Choose your primary metric BEFORE running any model.**

# %% [markdown]
# **Primary metric chosen:**
#
# **Justification (written before any model results):**

# %%
# YOUR CODE HERE
# Steps: prepare_dataset → encode → split → scale
#        dummy → LR (CV) → RF (CV) → grid search

# %% [markdown]
# ## 8. Business Evaluation
# Apply the Week 8 cost-benefit framework.

# %%
# Estimate business parameters from the dataset
# OFFER_COST  = 30   (consistent with pilot)
# CLV_SAVED   = ?    (estimate from MonthlyCharges × avg remaining tenure)
# MONTHLY_CAP = 500  (consistent with pilot)

# YOUR CODE HERE — cost_benefit_analysis(), optimal threshold, net value chart
# Include: extrapolation to full base with confidence range

# %% [markdown]
# ## 9. Fairness Audit
# Audit at least two segments. **Include `region`** — not examined in previous weeks.

# %%
# YOUR CODE HERE
# Sensitive attributes: Contract type AND region
# Metrics: Equal Opportunity Difference + FPR Parity Difference
# Chart: Fairness landscape (two panels)
# If any gap >10pp: document finding, propose mitigation, calculate cost

# %% [markdown]
# ## 10. Performance Journey Chart

# %%
# YOUR CODE HERE — all iterations from dummy baseline to tuned model

# %% [markdown]
# ## 11. Business Recommendation
# Three questions. Specific numbers. Plain language.

# %% [markdown]
# ### Business Recommendation
#
# **Does it work?**
#
# **Does it pay for itself?**
#
# **Can it be trusted?**

# %% [markdown]
# ## 12. Scope Expansion Proposal
# One page. Four sections. Specific ask with timeline.
#
# ### Section 1 — Current Scope and Results
#
# ### Section 2 — Proposed Expansion
#
# ### Section 3 — Risks and Requirements
#
# ### Section 4 — Recommendation and Timeline
# *(One specific ask. One measurable success criterion. Three milestones with dates.)*

# %% [markdown]
# ## 13. Four-Question Reflection
#
# **What worked that you did not expect to work?**
#
# **What did not work that you expected to work?**
#
# **What do you know now that you wish you had known at the start?**
#
# **What is the first thing you will do on your next project that you did not do on this one?**
# *(This is the most important question. Answer it with a concrete action, not a principle.)*

# %% [markdown]
# ## 14. Portfolio Letter
#
# ---
#
# To Whoever Reads This,
#
# This notebook is the capstone of a twelve-week data science internship at Kova Analytics.
#
# **What you will find:**
#
# **What you will not find:**
#
# **One thing I would change if I did this again:**
#
# **One thing I am proud of:**
#
# — [Your name], [Date]
#
# ---

# %% [markdown]
# ---
# ## ✅ Week 12 Complete
# Well done — Book 1 complete!
#
# ---
# *The Data Science Internship · github.com/InternshipInABook*
