# %% [markdown]
# <a href="https://colab.research.google.com/github/internshipinabook/data-science-internshipinabook/blob/main/notebooks/week11_presentation_STARTER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 11 — Presentation
# ### The Data Science Internship | Kova Analytics📘 Companion notebook for:
#
#
# **The Data Science Internship**
# Book 0 of 9 in the InternshipInABook™ Series
#
# This repository contains the practical exercises from the book.
#
#
# 📖 Complete internship experience:
#
#
# 1. Workplace scenarios
# 2. Mentor guidance
# 3. Reflection exercises
# 4. Portfolio
# 5. checkpoints
# 6. Capstone projects
#
#
# 👉 Get the complete book:
# https://selar.com/al990ay7ux
#
#
#
# # 🚀 Start Here
#
# Welcome to The Data Science Internship.
#
# If you are new to the InternshipInABook™ Series:
#
# 1. Run this setup notebook.
# 2. Complete Week 1.
# 3. Follow the weekly internship schedule.
# 4. Build your portfolio.
# 5. Complete the capstone project.
#
# 🔗 Repository:
# https://github.com/internshipinabook/data-science-internshipinabook
#
# Run every cell top to bottom. Each cell prints ✅ if everything is working or ❌ with a fix instruction.
# Complete every fix before moving to Week 1.
#
# ---

# %% [markdown]
# > ⏸️ **Pause and Predict**
# > Before opening any design tool: write the three questions Dana named — does it work, does it pay for itself, can we trust it — and write your one-sentence answer to each. Every slide in your deck answers one of these. Nothing else earns a place.

# %%
# ── Colab setup (skip if running locally) ────────────────────────────────────
import os
if not os.path.exists('requirements.txt'):
    # !git clone https://github.com/internshipinabook/data-science-internshipinabook.git book
    # %cd book
    # !pip install -r requirements.txt -q
    print('Colab setup complete ✅')
else:
    print('Running locally ✅')

# %% [markdown]
# # Week 11 — Executive Presentation
# ### Week 11 — The Data Science Internship | Kova Analytics
#
# > **STARTER notebook.**
#
# ---

# %% [markdown]
# ## 📝 About This Notebook
#
# **No dataset required.** All metrics come from Weeks 7–9.
# If you ran those weeks with different parameters, update the slide values accordingly.
#
# ## 🔄 Adaptability
#
# The `make_exec_slide()` helper works for **any executive presentation**.
# Change slide content, colours (`#1A3A5C`, `#2E75B6`), and metrics to match your own project.
#
# ---

# %% [markdown]
# ## ⚠️ Common Mistakes
#
# | Mistake | What goes wrong | Fix |
# |---------|-----------------|-----|
# | Leading with methodology, not results | The executive team does not care how Random Forest works. They care what it means for their budget. | Slide 1 states the situation. Slide 2 is the headline result. Methodology is an appendix if needed at all. |
# | Using technical terms without translation | 'Recall of 0.74' means nothing to a CFO. 'We correctly identify 74% of customers about to leave' means everything. | Every technical metric must appear in plain English with a business implication next to it |

# %% [markdown]
# ## 🏆 Challenge Task
#
# > 🎯 **Core Path**
# > Build all eight slides. Each slide must have a title that states the finding (not the topic), one visual or key number, and no more than three bullet points.
#
# > 🔬 **Advanced Path**
# > Write and rehearse a three-minute verbal pitch that covers all three questions without slides. Time yourself. If you go over three minutes, cut.

# %% [markdown]
# ## ✅ What You Can Do After This Week
#
# - Structure an executive presentation around three questions: does it work, pay for itself, and can it be trusted
# - Profile three distinct executive stakeholders and anticipate each one's primary concern
# - Build all eight slides programmatically using `make_exec_slide()`
# - Prepare and deliver honest answers to the three hardest questions — including the conservative floor
# - Write a four-section presentation report with Q&A documented in precise format
#
# *Add `week11_presentation.ipynb` to your internship portfolio.*

# %% [markdown]
# <a href="https://colab.research.google.com/github/internshipinabook/data-science-internshipinabook/blob/main/notebooks/week11_presentation_STARTER.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>&nbsp;&nbsp;
# <a href="https://github.com/internshipinabook/data-science-internshipinabook/blob/main/notebooks/week11/week11_presentation_STARTER.ipynb">
#   <img src="https://img.shields.io/badge/View%20on-GitHub-181717?logo=github" alt="View on GitHub"/>
# </a>
#
# ---
#
# ## 🖥️ How to Run This Notebook
#
# | Platform | Instructions |
# |----------|-------------|
# | **Google Colab** | Click the badge above — free, no setup needed |
# | **Local Jupyter** | `pip install -r requirements.txt` then `jupyter lab` |
# | **VS Code** | Open `.ipynb` with the Jupyter extension installed |
# | **GitHub** | Click "View on GitHub" above for a read-only preview |
#
# > **STARTER notebook** — Complete the `# YOUR CODE HERE` cells. Check the SOLUTION notebook if stuck.

# %%
# ── PLATFORM SETUP ───────────────────────────────────────────────────────────
# Run this cell first. It installs missing libraries in Google Colab.
# In a local environment, skip it if requirements.txt is already installed.

import sys, subprocess

IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    print("📦 Google Colab detected — installing libraries...")
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q',
                    'pandas>=1.5', 'numpy>=1.23', 'matplotlib>=3.6',
                    'seaborn>=0.12', 'scikit-learn>=1.2'], check=True)
    print("✅ Libraries installed.")
else:
    print("💻 Running locally.")
    print("   If you see ImportError below, run: pip install -r requirements.txt")

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Setup

# %%
import matplotlib.pyplot as plt, matplotlib.patches as mpatches, pandas as pd, numpy as np
print('✅ Ready')

# %%
import matplotlib.pyplot as plt, matplotlib.patches as mpatches

def make_exec_slide(title_text, subtitle='Kova Analytics | Churn Pilot Review'):
    fig = plt.figure(figsize=(13.33, 7.5)); fig.patch.set_facecolor('#FFFFFF')
    header = fig.add_axes([0, 0.86, 1, 0.14]); header.set_facecolor('#1A3A5C'); header.axis('off')
    header.text(0.04, 0.6, subtitle, color='white', fontsize=9.5, va='center', transform=header.transAxes)
    content = fig.add_axes([0.05, 0.05, 0.9, 0.77]); content.axis('off')
    content.text(0.0, 0.95, title_text, fontsize=18, fontweight='bold', color='#1A3A5C',
                 transform=content.transAxes, va='top')
    return fig, content
print('✅ make_exec_slide() defined')

# %% [markdown]
# ## Presentation Plan
#
# | Slide | Question | Finding-based title |
# |-------|----------|--------------------|
# | 1 | Context | |
# | 2 | Does it work? | |
# | 3 | Does it work? | |
# | 4 | Does it pay? | |
# | 5 | Can we trust it? | |
# | 6 | Pilot status | |
# | 7 | Recommendation | |
# | 8 | Next steps | |

# %% [markdown]
# ## Three-Minute Verbal Pitch
# *(Write the full presentation as spoken prose — no slides, no bullets)*
#
# *Your pitch here.*

# %% [markdown]
# ## Slide 1 — The Situation

# %%
# fig, content = make_exec_slide('The Business Problem')
# YOUR CODE HERE
# plt.savefig('slide1_situation.png', dpi=150, bbox_inches='tight', facecolor='white')

# %% [markdown]
# ## Slide 2 — The Headline ($18K–$24K centred, large)

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Slide 3 — Does It Work? (three metric boxes)

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Slide 4 — Does It Pay? (three effectiveness rows, cost assumptions visible)

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Slide 5 — Can We Trust It? (two columns, Month 2 commitment explicit)

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Slide 6 — Pilot Status

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Slide 7 — Recommendation

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Slide 8 — Next 90 Days

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Wednesday Review Checklist
# - [ ] Every slide title is a finding, not a label
# - [ ] Each slide answers exactly one of the three questions
# - [ ] Slide 4 shows cost assumptions: $30/offer, $240 CLV, 500/month cap
# - [ ] Slide 5 includes Month 2 audit commitment
# - [ ] No slide uses 'algorithm', 'model training', or 'confusion matrix'
# - [ ] Deck tells the same story as the verbal pitch
# - [ ] Eight slides or fewer

# %% [markdown]
# ## Prepared Q&A
#
# **Q: The $18K–$24K range is wide — which number for planning?**
#
# Your answer:
#
# **Q: Will customers know they are being scored?**
#
# Your answer:
#
# **Q: What happens if this damages customer relationships?**
#
# Your answer:

# %% [markdown]
# ## Presentation Report
#
# ### 1 — Summary
#
# ### 2 — Questions and Answers
# *(Q / Asked by / Answer given / Follow-up action)*
#
# ### 3 — Decisions Made
#
# ### 4 — Next Steps
#
# | Action | Owner | By When |
# |--------|-------|---------|

# %% [markdown]
# ---
# ## ✅ Week 11 Complete
# **Next:** `week12/*_STARTER.ipynb`
#
# ---
# *github.com/InternshipInABook*
