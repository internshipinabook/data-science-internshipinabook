# %% [markdown]
# <a href="https://colab.research.google.com/github/internshipinabook/data-science-internshipinabook/blob/main/notebooks/week1_first_look_STARTER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > ⏸️ **Pause and Predict**
# > Before running `.head()` and `.info()`: write down three things you expect to find in a customer churn dataset. What columns? What data types? What quality issues? Check your predictions after running.

# %%
# ── Colab setup (skip if running locally) ────────────────────────────────────
import os
if not os.path.exists('requirements.txt'):
    # !git clone https://github.com/internshipinabook/data-science-internshipinabook.git book
    # %cd book
    # !pip install -r requirements.txt -q
    print('Colab setup complete ✅')
else:
    print('Running locally ✅')

# %% [markdown]
# # Week 1 — First Look
# ### The Data Science Internship | Kova Analytics
#
# > **STARTER notebook.** Complete each `# YOUR CODE HERE` cell.
# > Check `week1_first_look_SOLUTION.ipynb` if you get stuck.
#
# ---

# %% [markdown]
# ## ⚠️ Common Mistakes
#
# | Mistake | What goes wrong | Fix |
# |---------|-----------------|-----|
# | Inspecting only `.head()` and moving on | One screen of data is not a dataset. Run `.describe()`, `.dtypes`, `.isnull().sum()`, and `.value_counts()` on key columns before writing a single finding. | Read the full data inventory — all methods above |
# | Writing findings as bullet points of observations | Dana wants a memo, not a list. Each finding should have a context, a number, and an implication. | Re-read your memo — every bullet should answer 'so what?' |

# %% [markdown]
# ## 🏆 Challenge Task
#
# > 🎯 **Core Path**
# > Write a one-paragraph EDA summary memo as if you are sending it to Dana. Include: dataset size, target variable, top data quality issue, and one business question this data could answer.
#
# > 🔬 **Advanced Path**
# > Identify which three columns you would drop immediately and why. Write a one-sentence justification for each.

# %% [markdown]
# ## ✅ What You Can Do After This Week
#
# - Load a dataset and perform a structured first-look investigation
# - Name every column and understand what it measures
# - Compute shape verification and flag unexpected values
# - Form and document three analytical questions before any modelling
# - Follow the six-step EDA workflow independently
#
# *Add `week1_first_look.ipynb` to your internship portfolio.*

# %% [markdown]
# <a href="https://colab.research.google.com/github/internshipinabook/data-science-internshipinabook/blob/main/notebooks/week1_first_look_STARTER.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>&nbsp;&nbsp;
# <a href="https://github.com/internshipinabook/data-science-internshipinabook/blob/main/notebooks/week1/week1_first_look_STARTER.ipynb">
#   <img src="https://img.shields.io/badge/View%20on-GitHub-181717?logo=github" alt="View on GitHub"/>
# </a>
#
# ---
#
# ## 🖥️ How to Run This Notebook
#
# | Platform | Instructions |
# |----------|-------------|
# | **Google Colab** | Click the badge above — free, no setup needed |
# | **Local Jupyter** | `pip install -r requirements.txt` then `jupyter lab` |
# | **VS Code** | Open `.ipynb` with the Jupyter extension installed |
# | **GitHub** | Click "View on GitHub" above for a read-only preview |
#
# > **STARTER notebook** — Complete the `# YOUR CODE HERE` cells. Check the SOLUTION notebook if stuck.

# %%
# ── PLATFORM SETUP ───────────────────────────────────────────────────────────
# Run this cell first. It installs missing libraries in Google Colab.
# In a local environment, skip it if requirements.txt is already installed.

import sys, subprocess

IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    print("📦 Google Colab detected — installing libraries...")
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q',
                    'pandas>=1.5', 'numpy>=1.23', 'matplotlib>=3.6',
                    'seaborn>=0.12', 'scikit-learn>=1.2'], check=True)
    print("✅ Libraries installed.")
else:
    print("💻 Running locally.")
    print("   If you see ImportError below, run: pip install -r requirements.txt")

# %% [markdown]
# ## 📂 Dataset
#
# The dataset is included in the course repository. No Kaggle account required.
#
# **File:** `supermarket_sales.csv`
# **Source:** `https://raw.githubusercontent.com/internshipinabook/data-science-internshipinabook/main/data/supermarket_sales.csv`
#
# Run the cell below to load it directly.

# %% [markdown]
# ## 🔄 Adaptability — Use Your Own Dataset
#
# This notebook uses `supermarket_sales.csv` but **every technique works on any tabular dataset**.
#
# **To swap in your own data, change only these four lines:**
# ```python
# DATA_FILE   = 'supermarket_sales.csv'  # ← your CSV filename
# DATE_COLS   = ['Date', 'Time']          # ← columns to parse as datetime (or [])
# TARGET_COL  = 'Total'                   # ← the column you want to analyse
# GROUP_COLS  = ['Branch', 'Product line']# ← categorical columns for grouped analysis
# ```
#
# **Works well with:** retail sales data, survey responses, HR records, student grades,
# weather data, sports statistics — any dataset with rows of observations and mixed column types.
#
# > 💡 **Tip:** If your dataset has no datetime columns, set `DATE_COLS = []` and skip Step 6.
#
# ---

# %% [markdown]
# ## Why This Week Matters
#
# Before building anything, you need to understand the data. This week you will learn the most
# important habit in data science: **observe before you act**.
#
# Taiwo opened a dataset and built a model on day one. Damilola asked questions first.
# This week, you are Damilola.
#
# The six questions you will answer:
# 1. What is in this dataset? (shape, columns, types)
# 2. What is missing?
# 3. What are the statistics?
# 4. What is surprising or suspicious?
# 5. What questions does the data raise?
# 6. What is one thing worth showing someone else?
#
# ---

# %% [markdown]
# ## Setup — Import Libraries

# %%
# Standard imports for data science work
# pandas — the core library for working with tabular data (DataFrames)
# numpy  — numerical operations (arrays, maths, random numbers)
# matplotlib/seaborn — plotting libraries

import pandas as pd          # DataFrames, CSV loading, data manipulation
import numpy as np           # Numerical computing
import matplotlib.pyplot as plt  # Base plotting library
import seaborn as sns        # Statistical visualisation (built on matplotlib)

# %matplotlib inline           # Display plots directly in the notebook
sns.set_theme(style='whitegrid')  # Clean chart background

print("✅ Libraries loaded — ready to begin")

# %% [markdown]
# ## 1. Load the Dataset

# %% [markdown]
# > 💡 **Tip:** `pd.read_csv()` reads a CSV file from disk into a DataFrame.
# > A DataFrame is a table — rows are observations, columns are variables.
# > If you get a `FileNotFoundError`, check that `supermarket_sales.csv` is in the same folder as this notebook.

# %%
import pandas as pd, os

# Smart loader — tries local package first, then GitHub, then generates sample data
LOCAL_PATH = '../data/supermarket_sales.csv'
REMOTE_URL = 'https://raw.githubusercontent.com/internshipinabook/data-science-internshipinabook/main/data/supermarket_sales.csv'

df = None
if os.path.exists(LOCAL_PATH):
    df = pd.read_csv(LOCAL_PATH)
    print(f'Loaded from local package ✅')
else:
    try:
        df = pd.read_csv(REMOTE_URL)
        print(f'Loaded from GitHub repository ✅')
    except Exception as e:
        print(f'⚠️  Dataset not yet available online ({e})')
        print('Generating sample data for now — upload supermarket_sales.csv to the data/ folder')
        import numpy as np; np.random.seed(42)
        df = pd.DataFrame({
            'Invoice ID': [f'INV-{i:04d}' for i in range(100)],
            'Branch': np.random.choice(['A','B','C'], 100),
            'City': np.random.choice(['Yangon','Mandalay','Naypyitaw'], 100),
            'Customer type': np.random.choice(['Member','Normal'], 100),
            'Gender': np.random.choice(['Male','Female'], 100),
            'Product line': np.random.choice(['Health and beauty','Electronic accessories','Food and beverages'], 100),
            'Unit price': np.round(np.random.uniform(10,100,100),2),
            'Quantity': np.random.randint(1,11,100),
            'Total': np.round(np.random.uniform(50,500,100),2),
            'Rating': np.round(np.random.uniform(4,10,100),1),
        })
        print('Sample dataset ready (100 rows) ✅')

print(f'Shape: {df.shape[0]:,} rows × {df.shape[1]} columns')
df.head()

# %% [markdown]
# ## 2. First Look — Shape and Columns

# %% [markdown]
# > 💡 **Three essential first-look commands:**
# > - `df.shape` — (rows, columns)
# > - `df.columns.tolist()` — list of column names
# > - `df.head()` — first 5 rows (rendered as a table in Jupyter)

# %%
# YOUR CODE HERE
# Print shape, columns, and display the first 5 rows

# %% [markdown]
# ## 3. Data Types and Missing Values

# %% [markdown]
# > 💡 **Why check data types first?**
# > A column containing dates stored as strings cannot be sorted as dates.
# > A column containing numbers stored as objects cannot be summed.
# > Catching type problems before analysis saves hours later.
#
# > ⚠️ **Common trap:** `df.info()` shows non-null counts, not missing counts.
# > Use `df.isnull().sum()` for a clear missing value count per column.

# %%
# YOUR CODE HERE
# Check data types with .info() or .dtypes
# Count missing values with .isnull().sum()

# %% [markdown]
# ## 4. Basic Statistics

# %% [markdown]
# > 💡 **`.describe()` gives you eight statistics per numerical column:**
# > count (non-missing rows), mean, std (spread), min, 25th percentile,
# > median (50th), 75th percentile, max.
# >
# > Look for: values that seem too large or too small, columns where min==max (constant), very high standard deviations.

# %%
# YOUR CODE HERE
# df.describe().round(2)

# %% [markdown]
# ## 5. Unique Value Count Per Column

# %% [markdown]
# > 💡 **Why unique value counts matter:**
# > A column with 1 unique value is a constant — it contains no information.
# > A column with as many unique values as rows is an identifier — not a feature.
# > Categorical columns should have a small, fixed number of unique values.

# %%
# YOUR CODE HERE
# For each column, print the number of unique values
# Hint: df[col].nunique() returns the count for one column

# %% [markdown]
# ## 6. Your Five Questions
#
# Write five questions the data itself raised — not questions about Python syntax.
# Good questions are specific: *"Why does `gross margin percentage` have only one unique value?"*
# not *"What does this column mean?"*
#
# > 💡 **Pro habit:** Write these BEFORE looking at answers. The questions you form before
# > you know the answers are the most valuable — they show what is genuinely unclear
# > and direct your investigation next week.

# %% [markdown]
# **Question 1:**
#
# **Question 2:**
#
# **Question 3:**
#
# **Question 4:**
#
# **Question 5:**

# %% [markdown]
# ## 7. One Surprising Finding
#
# Find the single most surprising thing in this dataset. It could be:
# - A column that has only one unique value (contains no information)
# - Two columns that seem to be perfectly correlated
# - A distribution that looks nothing like what you expected
# - A data type that seems wrong for what the column contains
#
# > 💡 **This is more important than it sounds.** The most valuable insight from Week 1
# > is often the thing that makes you say *"wait, that can't be right"* — then check, and discover it IS right.

# %%
# YOUR CODE HERE
# Produce one chart or statistic that illustrates your surprising finding
# Add a markdown cell below explaining what you found and why it matters

# %% [markdown]
# ### My Finding
# *Write what you found and why it is surprising.*

# %% [markdown]
# ---
# ## ✅ Week 1 Complete
# **Next:** `week2/week2_*_STARTER.ipynb`
#
# ---
# *The Data Science Internship · Kova Analytics · github.com/InternshipInABook*
